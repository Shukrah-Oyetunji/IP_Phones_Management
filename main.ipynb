# %%
#!pip install pandas openpyxl
#For data storage and excel reports

# %%
import pandas as pd

data = {
    "Date": [],
    "Agency": [],
    "Officer_in_charge": [],
    "Phone_Model": [],
    "Phone_number": [],
    "Digits_number": [],
    "Work_Type": [],
    "Fault": [],
    "Config_File": [],
    "New_Install": [],
    "Status": [],
    "Customer_Name": []
}

df = pd.DataFrame(data)

df.to_csv("phone_data.csv", index=False)

print("Database Ready")
# Out:
# Database Ready
